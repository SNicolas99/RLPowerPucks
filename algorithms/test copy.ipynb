# %%
import torch
import numpy as np
import gymnasium as gym

import sys
sys.path.append('../')
from tools.trainer import Trainer
from tools.logger import Logger
from environments.hockey_wrapper import HockeyWrapper
from TD3 import TD3Agent
import laserhockey.hockey_env as h_env

# %%
env_string = "LunarLanderContinuous-v2"

# %%
if env_string == "Hockey":
    env = HockeyWrapper(mode="normal", opponent="mixed", add_opponents=True)
else:
    env = gym.make(env_string)

# %%
agent = TD3Agent(env.observation_space, env.action_space)
trainer = Trainer()

# %%
logger = Logger(2000, 100)
logger.load('logs/lunar_lander_td3_no_double_q.npy')
logger.plot()

# %%
# player = h_env.BasicOpponent(weak=False)
player = agent

# %%
# state = torch.load("checkpoint_hockey.pth")
# agent.restore_state(state)
# logger = Logger(30000, 100)
# logger.load("logs/hockey_strong.npy")
# trainer.logger = logger

# %%
ep_rewards = trainer.train(env, agent, n_episodes=10000, test_every=100, noise=0.2, player=player, mixed=False)
# Out:
# Step 100/9999:
#                     test reward: -87.03
#                     mean reward: -254.31, max reward: 156.76
#                     Avg. step count: 136.3, Avg ep duration: 0.035s
#                     Avg. critic loss: 1.41, Avg. actor loss: 1.02
#                     Avg. train duration: 0.355s
#
#
# Step 200/9999:
#                     test reward: -92.19
#                     mean reward: -272.26, max reward: 33.08
#                     Avg. step count: 175.6, Avg ep duration: 0.046s
#                     Avg. critic loss: 1.05, Avg. actor loss: 0.81
#                     Avg. train duration: 0.346s
#
#
# Step 300/9999:
#                     test reward: -10.51
#                     mean reward: -340.37, max reward: 23.50
#                     Avg. step count: 242.7, Avg ep duration: 0.064s
#                     Avg. critic loss: 0.99, Avg. actor loss: 0.58
#                     Avg. train duration: 0.341s
#
#
# Step 400/9999:
#                     test reward: -31.51
#                     mean reward: -223.18, max reward: 79.05
#                     Avg. step count: 140.8, Avg ep duration: 0.035s
#                     Avg. critic loss: 0.96, Avg. actor loss: 0.29
#                     Avg. train duration: 0.326s
#
#
# Step 500/9999:
#                     test reward: -19.36
#                     mean reward: -117.97, max reward: 80.46
#                     Avg. step count: 161.6, Avg ep duration: 0.041s
#                     Avg. critic loss: 0.97, Avg. actor loss: -0.18
#                     Avg. train duration: 0.330s
#
#
# Step 600/9999:
#                     test reward: -33.95
#                     mean reward: -300.72, max reward: 92.37
#                     Avg. step count: 246.4, Avg ep duration: 0.062s
#                     Avg. critic loss: 0.95, Avg. actor loss: -0.58
#                     Avg. train duration: 0.330s
#
#
# Step 700/9999:
#                     test reward: -27.18
#                     mean reward: -287.69, max reward: 99.62
#                     Avg. step count: 186.9, Avg ep duration: 0.046s
#                     Avg. critic loss: 0.94, Avg. actor loss: -0.90
#                     Avg. train duration: 0.330s
#
#
# Step 800/9999:
#                     test reward: -25.15
#                     mean reward: -202.97, max reward: 80.91
#                     Avg. step count: 230.6, Avg ep duration: 0.057s
#                     Avg. critic loss: 0.87, Avg. actor loss: -1.12
#                     Avg. train duration: 0.328s
#
#
# Step 900/9999:
#                     test reward: -14.72
#                     mean reward: -132.68, max reward: 54.06
#                     Avg. step count: 258.9, Avg ep duration: 0.064s
#                     Avg. critic loss: 0.84, Avg. actor loss: -1.31
#                     Avg. train duration: 0.328s
#
#
# Step 1000/9999:
#                     test reward: -9.12
#                     mean reward: -172.22, max reward: 51.18
#                     Avg. step count: 221.8, Avg ep duration: 0.055s
#                     Avg. critic loss: 0.79, Avg. actor loss: -1.54
#                     Avg. train duration: 0.332s
#
#
# Step 1100/9999:
#                     test reward: -14.30
#                     mean reward: -137.61, max reward: 39.71
#                     Avg. step count: 181.8, Avg ep duration: 0.045s
#                     Avg. critic loss: 0.79, Avg. actor loss: -1.82
#                     Avg. train duration: 0.334s
#
#
# Step 1200/9999:
#                     test reward: -10.72
#                     mean reward: -294.54, max reward: 99.15
#                     Avg. step count: 206.6, Avg ep duration: 0.050s
#                     Avg. critic loss: 0.78, Avg. actor loss: -2.05
#                     Avg. train duration: 0.332s
#
#
# Step 1300/9999:
#                     test reward: 1.66
#                     mean reward: -251.80, max reward: 51.79
#                     Avg. step count: 207.7, Avg ep duration: 0.050s
#                     Avg. critic loss: 0.79, Avg. actor loss: -2.28
#                     Avg. train duration: 0.333s
#
#
# Step 1400/9999:
#                     test reward: -24.85
#                     mean reward: -231.05, max reward: 73.55
#                     Avg. step count: 184.3, Avg ep duration: 0.045s
#                     Avg. critic loss: 0.78, Avg. actor loss: -2.61
#                     Avg. train duration: 0.334s
#
#
# Step 1500/9999:
#                     test reward: -37.56
#                     mean reward: -190.04, max reward: 166.97
#                     Avg. step count: 211.3, Avg ep duration: 0.052s
#                     Avg. critic loss: 0.78, Avg. actor loss: -2.91
#                     Avg. train duration: 0.330s
#
#
# Step 1600/9999:
#                     test reward: -45.24
#                     mean reward: -160.12, max reward: 251.60
#                     Avg. step count: 170.7, Avg ep duration: 0.042s
#                     Avg. critic loss: 0.79, Avg. actor loss: -3.12
#                     Avg. train duration: 0.331s
#
#
# Step 1700/9999:
#                     test reward: -52.28
#                     mean reward: -310.19, max reward: 200.80
#                     Avg. step count: 222.7, Avg ep duration: 0.055s
#                     Avg. critic loss: 0.78, Avg. actor loss: -3.35
#                     Avg. train duration: 0.334s
#
#
# Step 1800/9999:
#                     test reward: -59.60
#                     mean reward: -359.38, max reward: 46.21
#                     Avg. step count: 209.9, Avg ep duration: 0.052s
#                     Avg. critic loss: 0.78, Avg. actor loss: -3.76
#                     Avg. train duration: 0.338s
#
#
# Step 1900/9999:
#                     test reward: -50.91
#                     mean reward: -168.14, max reward: 187.08
#                     Avg. step count: 131.8, Avg ep duration: 0.032s
#                     Avg. critic loss: 0.77, Avg. actor loss: -4.13
#                     Avg. train duration: 0.338s
#
#
# Step 2000/9999:
#                     test reward: -39.92
#                     mean reward: -270.90, max reward: 191.37
#                     Avg. step count: 203.1, Avg ep duration: 0.051s
#                     Avg. critic loss: 0.79, Avg. actor loss: -4.45
#                     Avg. train duration: 0.340s
#
#
# Step 2100/9999:
#                     test reward: -53.74
#                     mean reward: -97.52, max reward: 43.94
#                     Avg. step count: 159.2, Avg ep duration: 0.040s
#                     Avg. critic loss: 0.79, Avg. actor loss: -4.79
#                     Avg. train duration: 0.346s
#
#
# Step 2200/9999:
#                     test reward: -69.16
#                     mean reward: -153.58, max reward: 271.70
#                     Avg. step count: 115.8, Avg ep duration: 0.029s
#                     Avg. critic loss: 0.79, Avg. actor loss: -5.08
#                     Avg. train duration: 0.341s
#
#
# Step 2300/9999:
#                     test reward: -68.34
#                     mean reward: -108.44, max reward: 12.37
#                     Avg. step count: 120.4, Avg ep duration: 0.030s
#                     Avg. critic loss: 0.80, Avg. actor loss: -5.37
#                     Avg. train duration: 0.342s
#
#
# Step 2400/9999:
#                     test reward: -62.98
#                     mean reward: -151.79, max reward: 24.07
#                     Avg. step count: 78.4, Avg ep duration: 0.019s
#                     Avg. critic loss: 0.80, Avg. actor loss: -5.68
#                     Avg. train duration: 0.341s
#
#
# Step 2500/9999:
#                     test reward: -70.14
#                     mean reward: -140.76, max reward: 229.42
#                     Avg. step count: 162.4, Avg ep duration: 0.040s
#                     Avg. critic loss: 0.82, Avg. actor loss: -5.96
#                     Avg. train duration: 0.345s
#
#
# Step 2600/9999:
#                     test reward: -86.68
#                     mean reward: -217.42, max reward: 220.03
#                     Avg. step count: 247.7, Avg ep duration: 0.062s
#                     Avg. critic loss: 0.80, Avg. actor loss: -6.16
#                     Avg. train duration: 0.346s
#
#
# Step 2700/9999:
#                     test reward: -85.87
#                     mean reward: -147.08, max reward: 222.29
#                     Avg. step count: 157.1, Avg ep duration: 0.039s
#                     Avg. critic loss: 0.81, Avg. actor loss: -6.40
#                     Avg. train duration: 0.340s
#
#
# Step 2800/9999:
#                     test reward: -69.92
#                     mean reward: -205.28, max reward: 68.78
#                     Avg. step count: 202.0, Avg ep duration: 0.050s
#                     Avg. critic loss: 0.81, Avg. actor loss: -6.61
#                     Avg. train duration: 0.345s
#
#
# Step 2900/9999:
#                     test reward: -58.65
#                     mean reward: -234.84, max reward: 163.65
#                     Avg. step count: 205.2, Avg ep duration: 0.052s
#                     Avg. critic loss: 0.82, Avg. actor loss: -6.85
#                     Avg. train duration: 0.351s
#
#
# Step 3000/9999:
#                     test reward: -50.66
#                     mean reward: -250.23, max reward: 155.17
#                     Avg. step count: 214.2, Avg ep duration: 0.054s
#                     Avg. critic loss: 0.83, Avg. actor loss: -7.09
#                     Avg. train duration: 0.350s
#
#
# Step 3100/9999:
#                     test reward: -37.47
#                     mean reward: -130.65, max reward: 178.85
#                     Avg. step count: 164.2, Avg ep duration: 0.041s
#                     Avg. critic loss: 0.85, Avg. actor loss: -7.30
#                     Avg. train duration: 0.353s
#
#
# Step 3200/9999:
#                     test reward: -73.34
#                     mean reward: -193.27, max reward: 205.46
#                     Avg. step count: 201.7, Avg ep duration: 0.050s
#                     Avg. critic loss: 0.85, Avg. actor loss: -7.47
#                     Avg. train duration: 0.349s
#
#
# Step 3300/9999:
#                     test reward: -50.25
#                     mean reward: -136.93, max reward: 94.47
#                     Avg. step count: 114.6, Avg ep duration: 0.028s
#                     Avg. critic loss: 0.85, Avg. actor loss: -7.61
#                     Avg. train duration: 0.349s
#
#
# Step 3400/9999:
#                     test reward: -62.48
#                     mean reward: -108.41, max reward: 209.69
#                     Avg. step count: 85.4, Avg ep duration: 0.021s
#                     Avg. critic loss: 0.85, Avg. actor loss: -7.84
#                     Avg. train duration: 0.349s
#
#
# Step 3500/9999:
#                     test reward: -32.94
#                     mean reward: -229.39, max reward: 93.92
#                     Avg. step count: 177.3, Avg ep duration: 0.044s
#                     Avg. critic loss: 0.85, Avg. actor loss: -8.06
#                     Avg. train duration: 0.353s
#
#
# Step 3600/9999:
#                     test reward: -61.54
#                     mean reward: -96.86, max reward: 216.27
#                     Avg. step count: 132.1, Avg ep duration: 0.033s
#                     Avg. critic loss: 0.87, Avg. actor loss: -8.24
#                     Avg. train duration: 0.355s
#
#
# Step 3700/9999:
#                     test reward: -64.27
#                     mean reward: -232.21, max reward: 234.42
#                     Avg. step count: 124.3, Avg ep duration: 0.031s
#                     Avg. critic loss: 0.87, Avg. actor loss: -8.38
#                     Avg. train duration: 0.353s
#
#
# Step 3800/9999:
#                     test reward: 12.16
#                     mean reward: -288.73, max reward: 209.89
#                     Avg. step count: 193.6, Avg ep duration: 0.049s
#                     Avg. critic loss: 0.86, Avg. actor loss: -8.46
#                     Avg. train duration: 0.354s
#
#
# Step 3900/9999:
#                     test reward: 34.02
#                     mean reward: -79.46, max reward: 192.23
#                     Avg. step count: 129.6, Avg ep duration: 0.032s
#                     Avg. critic loss: 0.88, Avg. actor loss: -8.62
#                     Avg. train duration: 0.355s
#
#
# Step 4000/9999:
#                     test reward: 12.78
#                     mean reward: -240.16, max reward: 220.11
#                     Avg. step count: 143.9, Avg ep duration: 0.036s
#                     Avg. critic loss: 0.87, Avg. actor loss: -8.77
#                     Avg. train duration: 0.357s
#
#
# Step 4100/9999:
#                     test reward: 7.21
#                     mean reward: -134.44, max reward: 262.57
#                     Avg. step count: 126.5, Avg ep duration: 0.031s
#                     Avg. critic loss: 0.89, Avg. actor loss: -8.84
#                     Avg. train duration: 0.359s
#
#
# Step 4200/9999:
#                     test reward: -8.04
#                     mean reward: -108.90, max reward: 45.51
#                     Avg. step count: 128.4, Avg ep duration: 0.032s
#                     Avg. critic loss: 0.87, Avg. actor loss: -8.91
#                     Avg. train duration: 0.360s
#
#
# Step 4300/9999:
#                     test reward: 29.17
#                     mean reward: -152.27, max reward: 49.00
#                     Avg. step count: 113.8, Avg ep duration: 0.028s
#                     Avg. critic loss: 0.89, Avg. actor loss: -9.01
#                     Avg. train duration: 0.357s
#
#
# Step 4400/9999:
#                     test reward: 77.05
#                     mean reward: -407.51, max reward: 73.78
#                     Avg. step count: 136.5, Avg ep duration: 0.034s
#                     Avg. critic loss: 0.89, Avg. actor loss: -9.12
#                     Avg. train duration: 0.361s
#
#
# Step 4500/9999:
#                     test reward: 47.07
#                     mean reward: -208.08, max reward: 276.38
#                     Avg. step count: 200.1, Avg ep duration: 0.050s
#                     Avg. critic loss: 0.89, Avg. actor loss: -9.13
#                     Avg. train duration: 0.364s
#
#
# Step 4600/9999:
#                     test reward: 51.08
#                     mean reward: -148.30, max reward: 188.50
#                     Avg. step count: 178.9, Avg ep duration: 0.045s
#                     Avg. critic loss: 0.87, Avg. actor loss: -9.14
#                     Avg. train duration: 0.366s
#
#
# Step 4700/9999:
#                     test reward: 50.25
#                     mean reward: -78.53, max reward: 174.03
#                     Avg. step count: 143.5, Avg ep duration: 0.036s
#                     Avg. critic loss: 0.87, Avg. actor loss: -9.20
#                     Avg. train duration: 0.361s
#
#
# Step 4800/9999:
#                     test reward: 83.90
#                     mean reward: -97.86, max reward: 253.69
#                     Avg. step count: 96.3, Avg ep duration: 0.024s
#                     Avg. critic loss: 0.88, Avg. actor loss: -9.31
#                     Avg. train duration: 0.365s
#
#
# Step 4900/9999:
#                     test reward: 88.12
#                     mean reward: -268.59, max reward: 209.79
#                     Avg. step count: 164.9, Avg ep duration: 0.042s
#                     Avg. critic loss: 0.88, Avg. actor loss: -9.40
#                     Avg. train duration: 0.370s
#
#
# Step 5000/9999:
#                     test reward: 81.80
#                     mean reward: -144.12, max reward: 174.54
#                     Avg. step count: 111.2, Avg ep duration: 0.028s
#                     Avg. critic loss: 0.86, Avg. actor loss: -9.51
#                     Avg. train duration: 0.376s
#
#
# Step 5100/9999:
#                     test reward: 112.29
#                     mean reward: -96.15, max reward: 259.89
#                     Avg. step count: 89.7, Avg ep duration: 0.023s
#                     Avg. critic loss: 0.86, Avg. actor loss: -9.69
#                     Avg. train duration: 0.380s
#
#
# Step 5200/9999:
#                     test reward: 116.95
#                     mean reward: -88.47, max reward: 164.59
#                     Avg. step count: 117.3, Avg ep duration: 0.029s
#                     Avg. critic loss: 0.86, Avg. actor loss: -9.83
#                     Avg. train duration: 0.369s
#
#
# Step 5300/9999:
#                     test reward: 123.22
#                     mean reward: -234.73, max reward: 109.51
#                     Avg. step count: 122.4, Avg ep duration: 0.031s
#                     Avg. critic loss: 0.85, Avg. actor loss: -9.96
#                     Avg. train duration: 0.381s
#
#
# Step 5400/9999:
#                     test reward: 104.55
#                     mean reward: -70.77, max reward: 294.91
#                     Avg. step count: 120.9, Avg ep duration: 0.031s
#                     Avg. critic loss: 0.84, Avg. actor loss: -10.00
#                     Avg. train duration: 0.376s
#
#
# Step 5500/9999:
#                     test reward: 111.08
#                     mean reward: -122.69, max reward: 287.36
#                     Avg. step count: 123.0, Avg ep duration: 0.031s
#                     Avg. critic loss: 0.85, Avg. actor loss: -10.05
#                     Avg. train duration: 0.379s
#
#
# Step 5600/9999:
#                     test reward: 144.74
#                     mean reward: -178.45, max reward: 273.48
#                     Avg. step count: 132.0, Avg ep duration: 0.033s
#                     Avg. critic loss: 0.85, Avg. actor loss: -10.19
#                     Avg. train duration: 0.379s
#
#
# Step 5700/9999:
#                     test reward: 135.06
#                     mean reward: -117.95, max reward: 257.20
#                     Avg. step count: 198.1, Avg ep duration: 0.050s
#                     Avg. critic loss: 0.85, Avg. actor loss: -10.25
#                     Avg. train duration: 0.376s
#
#
# Step 5800/9999:
#                     test reward: 110.99
#                     mean reward: -227.37, max reward: 281.98
#                     Avg. step count: 167.8, Avg ep duration: 0.043s
#                     Avg. critic loss: 0.86, Avg. actor loss: -10.33
#                     Avg. train duration: 0.385s
#
#
# Step 5900/9999:
#                     test reward: 145.94
#                     mean reward: -111.87, max reward: 183.62
#                     Avg. step count: 80.8, Avg ep duration: 0.020s
#                     Avg. critic loss: 0.86, Avg. actor loss: -10.41
#                     Avg. train duration: 0.387s
#
#
# Step 6000/9999:
#                     test reward: 98.14
#                     mean reward: -215.88, max reward: 225.19
#                     Avg. step count: 210.2, Avg ep duration: 0.053s
#                     Avg. critic loss: 0.87, Avg. actor loss: -10.51
#                     Avg. train duration: 0.384s
#
#
# Step 6100/9999:
#                     test reward: 77.10
#                     mean reward: -195.15, max reward: 277.52
#                     Avg. step count: 197.4, Avg ep duration: 0.049s
#                     Avg. critic loss: 0.87, Avg. actor loss: -10.57
#                     Avg. train duration: 0.386s
#
#
# Step 6200/9999:
#                     test reward: 92.66
#                     mean reward: -94.82, max reward: 276.02
#                     Avg. step count: 98.8, Avg ep duration: 0.025s
#                     Avg. critic loss: 0.88, Avg. actor loss: -10.58
#                     Avg. train duration: 0.391s
#
#
# Step 6300/9999:
#                     test reward: 170.52
#                     mean reward: -97.78, max reward: 287.77
#                     Avg. step count: 138.9, Avg ep duration: 0.035s
#                     Avg. critic loss: 0.87, Avg. actor loss: -10.72
#                     Avg. train duration: 0.389s
#
#
# Step 6400/9999:
#                     test reward: 111.28
#                     mean reward: -56.63, max reward: 271.58
#                     Avg. step count: 122.0, Avg ep duration: 0.030s
#                     Avg. critic loss: 0.87, Avg. actor loss: -10.87
#                     Avg. train duration: 0.392s
#
#
# Step 6500/9999:
#                     test reward: 90.15
#                     mean reward: -170.95, max reward: 209.65
#                     Avg. step count: 110.8, Avg ep duration: 0.028s
#                     Avg. critic loss: 0.86, Avg. actor loss: -11.00
#                     Avg. train duration: 0.392s
#
#
# Step 6600/9999:
#                     test reward: 105.44
#                     mean reward: -84.56, max reward: 326.28
#                     Avg. step count: 131.7, Avg ep duration: 0.035s
#                     Avg. critic loss: 0.87, Avg. actor loss: -11.11
#                     Avg. train duration: 0.411s
#
#
# Step 6700/9999:
#                     test reward: 66.18
#                     mean reward: -207.11, max reward: 247.24
#                     Avg. step count: 158.5, Avg ep duration: 0.040s
#                     Avg. critic loss: 0.86, Avg. actor loss: -11.21
#                     Avg. train duration: 0.387s
#
#
# Step 6800/9999:
#                     test reward: 90.07
#                     mean reward: -239.79, max reward: 284.94
#                     Avg. step count: 153.7, Avg ep duration: 0.039s
#                     Avg. critic loss: 0.88, Avg. actor loss: -11.25
#                     Avg. train duration: 0.389s
#
#
# Step 6900/9999:
#                     test reward: 89.98
#                     mean reward: -84.87, max reward: 206.82
#                     Avg. step count: 101.4, Avg ep duration: 0.026s
#                     Avg. critic loss: 0.89, Avg. actor loss: -11.27
#                     Avg. train duration: 0.399s
#
#
# Step 7000/9999:
#                     test reward: 105.72
#                     mean reward: -75.88, max reward: 243.39
#                     Avg. step count: 120.5, Avg ep duration: 0.030s
#                     Avg. critic loss: 0.87, Avg. actor loss: -11.42
#                     Avg. train duration: 0.385s
#
#
# Step 7100/9999:
#                     test reward: 83.97
#                     mean reward: -108.50, max reward: 306.68
#                     Avg. step count: 101.0, Avg ep duration: 0.025s
#                     Avg. critic loss: 0.88, Avg. actor loss: -11.58
#                     Avg. train duration: 0.382s
#
#
# Step 7200/9999:
#                     test reward: 97.11
#                     mean reward: -188.33, max reward: 243.73
#                     Avg. step count: 125.7, Avg ep duration: 0.032s
#                     Avg. critic loss: 0.89, Avg. actor loss: -11.79
#                     Avg. train duration: 0.397s
#
#
# Step 7300/9999:
#                     test reward: 93.32
#                     mean reward: -299.91, max reward: 283.13
#                     Avg. step count: 189.5, Avg ep duration: 0.047s
#                     Avg. critic loss: 0.89, Avg. actor loss: -12.01
#                     Avg. train duration: 0.384s
#
#
# Step 7400/9999:
#                     test reward: 93.20
#                     mean reward: -60.53, max reward: 296.51
#                     Avg. step count: 128.0, Avg ep duration: 0.032s
#                     Avg. critic loss: 0.91, Avg. actor loss: -12.00
#                     Avg. train duration: 0.387s
#
#
# Step 7500/9999:
#                     test reward: 97.94
#                     mean reward: -170.94, max reward: 266.96
#                     Avg. step count: 177.6, Avg ep duration: 0.044s
#                     Avg. critic loss: 0.92, Avg. actor loss: -12.03
#                     Avg. train duration: 0.390s

# %%
trainer.logger.plot()

# %%
def play(env_string, agent, n_episodes=10, noise=0, opponent='strong', render=None):
    if env_string == 'Hockey':
        env = HockeyWrapper(mode='normal', opponent=opponent)
        if render is None:
            render = True
    else:
        env = gym.make(env_string, render_mode='human')
        render = False
    # player = h_env.BasicOpponent(weak=False)
    player = agent
    steps, rewards, observations, actions, results = Trainer.run(env, player, n_episodes=n_episodes, noise=noise, render=render, store_transitions=False, hockey=env_string=='Hockey')
    env.close()
    return steps, rewards, observations, actions, results

# %%
test_opp = h_env.BasicOpponent(weak=False)
# test_opp = env.opponent_list[3]

# %%
steps, rewards, observations, actions, results = play(env_string, agent, n_episodes=2, noise=0, render=True, opponent=test_opp)
print(np.mean(rewards))
# print(np.mean(results==1), np.mean(results==0), np.mean(results==-1))
# Out:
# 125.96660260792788

# %%
# steps, rewards, observations, actions, results = play(env_string, agent, n_episodes=100, noise=0, render=False, opponent=test_opp)
# print(np.mean(rewards))
# # print(np.mean(results==1), np.mean(results==0), np.mean(results==-1))

# %%
trainer.logger.save("logs/lunar_tau_0_001.npy")

# %%
torch.save(agent.state(), 'checkpoint_lunar_tau_0_001.pth')

# %%
# agent_state = torch.load('checkpoint_hockey.pth')
# agent.restore_state(agent_state)
