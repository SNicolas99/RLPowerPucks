# %%
import torch
import numpy as np
import gymnasium as gym
from matplotlib import pyplot as plt
from td3 import TD3
import laserhockey.hockey_env as h_env
import laserhockey.laser_hockey_env as lh

# %%
env_string = "LunarLander-v2"

# %%
hockey_opponent = None
if env_string == "LunarLander-v2":
    env = gym.make(env_string, continuous=True)
elif env_string == "HockeyEnv":
    env = h_env.HockeyEnv(mode=h_env.HockeyEnv.NORMAL)
    hockey_opponent = h_env.BasicOpponent(weak=False)
elif env_string == "LaserHockeyEnv":
    env = lh.LaserHockeyEnv(mode=lh.LaserHockeyEnv.NORMAL)
    hockey_opponent = lh.BasicOpponent()
else:
    env = gym.make(env_string)

# %%
agent = TD3(
    env,
    env_string=env_string,
    epochs=45000,
    steps_max=1000,
    action_noise_scale=0.35,
    prioritized_replay=False,
    gradient_steps=-1,
    hockey_opponent=hockey_opponent,
    noise_mode="ornstein-uhlenbeck",
    h=64,
    gamma=0.99,
    batch_size=128,
    policy_update_freq=2,
    target_action_noise_scale=0.1,
    buffer_size=10000,
)

# %%
# agent.total_steps = 2000
# agent.test(render_mode="human", noise_enabled=True)

# %%
# agent.env.close()

# %%
(
    episode_rewards,
    test_rewards,
    episode_steps,
    ep_durations,
    upd_durations,
    ep_actor_losses,
    ep_critic_losses,
) = agent.train()
# Out:
# Epoch 10:
#                                 rewards: train: -396.98, test: -285.53
#                                             max train reward: -92.13
#                                 avg_steps: 118.10
#                                 losses:
#                                     actor: mean: 3.57, first: 2.45, last: 4.58
#                                     critic: mean: 1.80, first: 2.11, last: 1.87
#                                 avg_duration: 0.01, upd_duration: 0.47
#
# Epoch 20:
#                                 rewards: train: -450.38, test: -262.10
#                                             max train reward: -71.27
#                                 avg_steps: 118.40
#                                 losses:
#                                     actor: mean: 33.59, first: 32.39, last: 33.44
#                                     critic: mean: 1.71, first: 1.64, last: 1.47
#                                 avg_duration: 0.01, upd_duration: 0.34
#
# Epoch 30:
#                                 rewards: train: -38.48, test: -274.04
#                                             max train reward: -38.48
#                                 avg_steps: 103.70
#                                 losses:
#                                     actor: mean: 41.31, first: 40.60, last: 41.53
#                                     critic: mean: 1.52, first: 1.48, last: 1.44
#                                 avg_duration: 0.01, upd_duration: 0.28
#
# Epoch 40:
#                                 rewards: train: -47.64, test: -234.38
#                                             max train reward: 25.56
#                                 avg_steps: 115.30
#                                 losses:
#                                     actor: mean: 60.51, first: 59.21, last: 61.68
#                                     critic: mean: 1.34, first: 1.26, last: 1.51
#                                 avg_duration: 0.01, upd_duration: 0.32
#
# Epoch 50:
#                                 rewards: train: -159.93, test: -220.16
#                                             max train reward: -26.41
#                                 avg_steps: 104.00
#                                 losses:
#                                     actor: mean: 77.09, first: 76.04, last: 77.54
#                                     critic: mean: 1.09, first: 1.06, last: 1.12
#                                 avg_duration: 0.01, upd_duration: 0.34
#
# Epoch 60:
#                                 rewards: train: -314.74, test: -133.04
#                                             max train reward: -70.80
#                                 avg_steps: 111.30
#                                 losses:
#                                     actor: mean: 86.11, first: 85.83, last: 86.19
#                                     critic: mean: 0.99, first: 0.97, last: 1.08
#                                 avg_duration: 0.01, upd_duration: 0.31
#
# Epoch 70:
#                                 rewards: train: -106.96, test: -268.69
#                                             max train reward: -86.65
#                                 avg_steps: 107.90
#                                 losses:
#                                     actor: mean: 92.47, first: 92.11, last: 92.73
#                                     critic: mean: 1.00, first: 1.01, last: 0.89
#                                 avg_duration: 0.01, upd_duration: 0.31
#
# Epoch 80:
#                                 rewards: train: -181.67, test: -245.50
#                                             max train reward: -55.28
#                                 avg_steps: 101.50
#                                 losses:
#                                     actor: mean: 77.45, first: 78.77, last: 75.99
#                                     critic: mean: 0.90, first: 0.89, last: 0.89
#                                 avg_duration: 0.01, upd_duration: 0.30
#
# Epoch 90:
#                                 rewards: train: -394.06, test: -240.74
#                                             max train reward: -54.28
#                                 avg_steps: 94.90
#                                 losses:
#                                     actor: mean: 47.41, first: 48.90, last: 45.54
#                                     critic: mean: 0.99, first: 0.92, last: 0.95
#                                 avg_duration: 0.01, upd_duration: 0.26
#
# Epoch 100:
#                                 rewards: train: -396.05, test: -28.27
#                                             max train reward: -17.83
#                                 avg_steps: 462.10
#                                 losses:
#                                     actor: mean: -37.05, first: -31.26, last: -43.21
#                                     critic: mean: 1.86, first: 1.50, last: 2.14
#                                 avg_duration: 0.06, upd_duration: 1.34
#
# Epoch 110:
#                                 rewards: train: -167.91, test: -103.35
#                                             max train reward: -2.59
#                                 avg_steps: 579.60
#                                 losses:
#                                     actor: mean: -57.54, first: -59.27, last: -58.44
#                                     critic: mean: 4.86, first: 4.88, last: 5.04
#                                 avg_duration: 0.09, upd_duration: 1.71
#
# Epoch 120:
#                                 rewards: train: -64.63, test: -130.93
#                                             max train reward: 9.67
#                                 avg_steps: 252.10
#                                 losses:
#                                     actor: mean: -37.12, first: -37.74, last: -36.81
#                                     critic: mean: 2.80, first: 2.85, last: 2.90
#                                 avg_duration: 0.04, upd_duration: 0.78
#
# Epoch 130:
#                                 rewards: train: -466.41, test: -312.09
#                                             max train reward: -77.00
#                                 avg_steps: 181.00
#                                 losses:
#                                     actor: mean: -31.09, first: -31.53, last: -31.02
#                                     critic: mean: 1.90, first: 2.07, last: 2.07
#                                 avg_duration: 0.03, upd_duration: 0.57
#
# Epoch 140:
#                                 rewards: train: -473.36, test: -172.58
#                                             max train reward: -39.20
#                                 avg_steps: 223.80
#                                 losses:
#                                     actor: mean: -27.83, first: -26.53, last: -28.44
#                                     critic: mean: 1.89, first: 1.65, last: 1.99
#                                 avg_duration: 0.03, upd_duration: 0.66
#
# Epoch 150:
#                                 rewards: train: -123.40, test: -129.38
#                                             max train reward: -84.14
#                                 avg_steps: 446.10
#                                 losses:
#                                     actor: mean: -37.99, first: -38.13, last: -36.70
#                                     critic: mean: 1.32, first: 1.46, last: 1.16
#                                 avg_duration: 0.06, upd_duration: 1.32
#
# Epoch 160:
#                                 rewards: train: 1.11, test: -11.58
#                                             max train reward: 1.11
#                                 avg_steps: 313.50
#                                 losses:
#                                     actor: mean: -32.06, first: -33.41, last: -30.90
#                                     critic: mean: 1.00, first: 0.88, last: 0.74
#                                 avg_duration: 0.05, upd_duration: 0.94
#
# Epoch 170:
#                                 rewards: train: -431.21, test: -53.82
#                                             max train reward: 34.91
#                                 avg_steps: 234.90
#                                 losses:
#                                     actor: mean: -7.17, first: -9.65, last: -7.15
#                                     critic: mean: 1.07, first: 0.88, last: 1.15
#                                 avg_duration: 0.04, upd_duration: 0.73
#
# Epoch 180:
#                                 rewards: train: -153.97, test: -80.09
#                                             max train reward: 33.39
#                                 avg_steps: 280.70
#                                 losses:
#                                     actor: mean: 4.20, first: 5.93, last: 4.19
#                                     critic: mean: 1.23, first: 1.28, last: 1.31
#                                 avg_duration: 0.04, upd_duration: 0.86
#
# Epoch 190:
#                                 rewards: train: -127.63, test: -61.11
#                                             max train reward: -21.65
#                                 avg_steps: 448.60
#                                 losses:
#                                     actor: mean: -1.31, first: -0.99, last: -2.97
#                                     critic: mean: 1.40, first: 1.38, last: 1.42
#                                 avg_duration: 0.07, upd_duration: 1.38
#
# Epoch 200:
#                                 rewards: train: -58.14, test: -124.68
#                                             max train reward: 215.07
#                                 avg_steps: 461.10
#                                 losses:
#                                     actor: mean: -13.52, first: -13.78, last: -13.65
#                                     critic: mean: 1.10, first: 1.35, last: 0.79
#                                 avg_duration: 0.07, upd_duration: 1.45
#
# Epoch 210:
#                                 rewards: train: 112.23, test: -142.79
#                                             max train reward: 112.23
#                                 avg_steps: 465.70
#                                 losses:
#                                     actor: mean: -12.77, first: -12.52, last: -12.29
#                                     critic: mean: 0.79, first: 0.91, last: 0.57
#                                 avg_duration: 0.07, upd_duration: 1.43
#
# Epoch 220:
#                                 rewards: train: -129.45, test: -189.34
#                                             max train reward: -42.60
#                                 avg_steps: 180.80
#                                 losses:
#                                     actor: mean: -0.74, first: -1.29, last: -0.62
#                                     critic: mean: 1.06, first: 0.90, last: 1.03
#                                 avg_duration: 0.03, upd_duration: 0.56
#
# Epoch 230:
#                                 rewards: train: -103.04, test: -147.25
#                                             max train reward: -26.64
#                                 avg_steps: 745.70
#                                 losses:
#                                     actor: mean: -7.33, first: -6.89, last: -8.14
#                                     critic: mean: 0.82, first: 0.75, last: 0.85
#                                 avg_duration: 0.10, upd_duration: 2.35
#
# Epoch 240:
#                                 rewards: train: -103.71, test: -112.69
#                                             max train reward: -43.18
#                                 avg_steps: 465.50
#                                 losses:
#                                     actor: mean: -8.34, first: -8.93, last: -8.69
#                                     critic: mean: 0.62, first: 0.63, last: 0.60
#                                 avg_duration: 0.07, upd_duration: 1.34
#
# Epoch 250:
#                                 rewards: train: -84.61, test: -105.62
#                                             max train reward: -57.54
#                                 avg_steps: 175.30
#                                 losses:
#                                     actor: mean: -7.39, first: -8.18, last: -7.22
#                                     critic: mean: 0.60, first: 0.67, last: 0.60
#                                 avg_duration: 0.03, upd_duration: 0.51
#
# Epoch 260:
#                                 rewards: train: -147.29, test: -208.58
#                                             max train reward: -79.36
#                                 avg_steps: 371.90
#                                 losses:
#                                     actor: mean: -0.91, first: -1.79, last: -0.94
#                                     critic: mean: 0.68, first: 0.67, last: 0.73
#                                 avg_duration: 0.05, upd_duration: 1.09
#
# Epoch 270:
#                                 rewards: train: -103.64, test: -88.16
#                                             max train reward: 201.20
#                                 avg_steps: 414.90
#                                 losses:
#                                     actor: mean: -9.58, first: -10.16, last: -10.08
#                                     critic: mean: 0.97, first: 1.03, last: 0.86
#                                 avg_duration: 0.06, upd_duration: 1.21
#
# Epoch 280:
#                                 rewards: train: -123.06, test: -221.64
#                                             max train reward: -47.48
#                                 avg_steps: 555.70
#                                 losses:
#                                     actor: mean: 5.72, first: 5.65, last: 6.12
#                                     critic: mean: 1.13, first: 0.96, last: 1.13
#                                 avg_duration: 0.08, upd_duration: 1.56
#
# Epoch 290:
#                                 rewards: train: -180.41, test: -153.20
#                                             max train reward: -58.87
#                                 avg_steps: 503.60
#                                 losses:
#                                     actor: mean: -3.28, first: -2.12, last: -3.36
#                                     critic: mean: 1.20, first: 1.59, last: 1.47
#                                 avg_duration: 0.07, upd_duration: 1.47
#
# Epoch 300:
#                                 rewards: train: -110.96, test: -133.54
#                                             max train reward: -81.93
#                                 avg_steps: 286.70
#                                 losses:
#                                     actor: mean: -1.59, first: -1.99, last: -1.09
#                                     critic: mean: 0.98, first: 1.04, last: 0.71
#                                 avg_duration: 0.04, upd_duration: 0.84
#
# Epoch 310:
#                                 rewards: train: -147.85, test: -277.08
#                                             max train reward: -8.00
#                                 avg_steps: 366.70
#                                 losses:
#                                     actor: mean: 15.03, first: 13.63, last: 15.29
#                                     critic: mean: 1.15, first: 1.18, last: 1.04
#                                 avg_duration: 0.05, upd_duration: 1.07
#
# Epoch 320:
#                                 rewards: train: 261.51, test: 74.71
#                                             max train reward: 261.51
#                                 avg_steps: 447.80
#                                 losses:
#                                     actor: mean: -6.33, first: -6.02, last: -7.32
#                                     critic: mean: 1.24, first: 1.35, last: 1.14
#                                 avg_duration: 0.06, upd_duration: 1.31
#
# Epoch 330:
#                                 rewards: train: -94.90, test: 87.82
#                                             max train reward: 276.80
#                                 avg_steps: 348.50
#                                 losses:
#                                     actor: mean: -9.45, first: -10.34, last: -9.36
#                                     critic: mean: 1.07, first: 1.24, last: 1.06
#                                 avg_duration: 0.05, upd_duration: 1.01
#
# Epoch 340:
#                                 rewards: train: -230.32, test: 119.93
#                                             max train reward: -49.93
#                                 avg_steps: 472.10
#                                 losses:
#                                     actor: mean: -0.12, first: -0.61, last: 0.21
#                                     critic: mean: 0.92, first: 1.25, last: 1.10
#                                 avg_duration: 0.07, upd_duration: 1.40
#
# Epoch 350:
#                                 rewards: train: -69.59, test: 34.50
#                                             max train reward: 220.30
#                                 avg_steps: 451.00
#                                 losses:
#                                     actor: mean: 0.82, first: 0.85, last: -0.22
#                                     critic: mean: 1.02, first: 0.86, last: 1.01
#                                 avg_duration: 0.06, upd_duration: 1.34
#
# Epoch 360:
#                                 rewards: train: -148.25, test: -85.86
#                                             max train reward: 12.31
#                                 avg_steps: 523.10
#                                 losses:
#                                     actor: mean: -4.37, first: -4.20, last: -5.00
#                                     critic: mean: 0.87, first: 0.75, last: 1.26
#                                 avg_duration: 0.07, upd_duration: 1.53
#
# Epoch 370:
#                                 rewards: train: -330.52, test: -3.51
#                                             max train reward: 39.25
#                                 avg_steps: 393.10
#                                 losses:
#                                     actor: mean: -11.95, first: -11.40, last: -12.39
#                                     critic: mean: 0.73, first: 0.73, last: 0.84
#                                 avg_duration: 0.05, upd_duration: 1.14
#
# Epoch 380:
#                                 rewards: train: 11.72, test: -35.17
#                                             max train reward: 197.87
#                                 avg_steps: 305.80
#                                 losses:
#                                     actor: mean: -13.59, first: -13.40, last: -13.15
#                                     critic: mean: 0.94, first: 1.04, last: 0.80
#                                 avg_duration: 0.04, upd_duration: 0.88
#
# Epoch 390:
#                                 rewards: train: 260.93, test: -328.43
#                                             max train reward: 260.93
#                                 avg_steps: 302.10
#                                 losses:
#                                     actor: mean: -11.85, first: -11.31, last: -11.73
#                                     critic: mean: 1.25, first: 1.46, last: 1.25
#                                 avg_duration: 0.04, upd_duration: 0.88
#
# Epoch 400:
#                                 rewards: train: -174.52, test: 5.73
#                                             max train reward: 254.56
#                                 avg_steps: 450.20
#                                 losses:
#                                     actor: mean: -15.24, first: -14.61, last: -16.31
#                                     critic: mean: 2.11, first: 2.48, last: 1.72
#                                 avg_duration: 0.06, upd_duration: 1.33
#
# Epoch 410:
#                                 rewards: train: 5.06, test: -104.37
#                                             max train reward: 174.46
#                                 avg_steps: 190.90
#                                 losses:
#                                     actor: mean: -17.90, first: -17.02, last: -17.47
#                                     critic: mean: 1.86, first: 1.57, last: 1.62
#                                 avg_duration: 0.03, upd_duration: 0.54
#
# Epoch 420:
#                                 rewards: train: -319.86, test: -190.84
#                                             max train reward: -11.00
#                                 avg_steps: 301.90
#                                 losses:
#                                     actor: mean: -16.26, first: -16.12, last: -15.90
#                                     critic: mean: 1.75, first: 1.69, last: 1.78
#                                 avg_duration: 0.04, upd_duration: 0.87
#
# Epoch 430:
#                                 rewards: train: 124.16, test: 23.89
#                                             max train reward: 124.16
#                                 avg_steps: 326.10
#                                 losses:
#                                     actor: mean: -13.73, first: -13.50, last: -13.91
#                                     critic: mean: 1.48, first: 1.68, last: 1.57
#                                 avg_duration: 0.05, upd_duration: 0.94
#
# Epoch 440:
#                                 rewards: train: -192.17, test: -98.46
#                                             max train reward: -43.10
#                                 avg_steps: 530.00
#                                 losses:
#                                     actor: mean: -8.78, first: -9.75, last: -7.27
#                                     critic: mean: 1.29, first: 1.18, last: 1.31
#                                 avg_duration: 0.07, upd_duration: 1.55
#
# Epoch 450:
#                                 rewards: train: 95.09, test: 14.75
#                                             max train reward: 199.49
#                                 avg_steps: 482.40
#                                 losses:
#                                     actor: mean: -10.98, first: -11.16, last: -11.55
#                                     critic: mean: 0.86, first: 1.06, last: 0.95
#                                 avg_duration: 0.07, upd_duration: 1.41
#
# Epoch 460:
#                                 rewards: train: -90.22, test: -262.55
#                                             max train reward: 196.72
#                                 avg_steps: 468.30
#                                 losses:
#                                     actor: mean: -3.47, first: -5.95, last: -2.78
#                                     critic: mean: 1.14, first: 1.05, last: 1.13
#                                 avg_duration: 0.07, upd_duration: 1.34
#
# Epoch 470:
#                                 rewards: train: -67.94, test: -8.09
#                                             max train reward: 294.82
#                                 avg_steps: 318.30
#                                 losses:
#                                     actor: mean: 22.47, first: 21.61, last: 22.27
#                                     critic: mean: 1.88, first: 1.79, last: 1.97
#                                 avg_duration: 0.05, upd_duration: 0.91
#
# Epoch 480:
#                                 rewards: train: -88.07, test: -121.66
#                                             max train reward: 4.68
#                                 avg_steps: 238.70
#                                 losses:
#                                     actor: mean: 11.80, first: 10.40, last: 11.17
#                                     critic: mean: 2.27, first: 2.00, last: 1.73
#                                 avg_duration: 0.03, upd_duration: 0.69
#
# Epoch 490:
#                                 rewards: train: -465.02, test: -132.52
#                                             max train reward: 144.07
#                                 avg_steps: 315.10
#                                 losses:
#                                     actor: mean: 2.10, first: 3.93, last: 1.31
#                                     critic: mean: 1.77, first: 2.22, last: 1.56
#                                 avg_duration: 0.05, upd_duration: 0.93
#
# Epoch 500:
#                                 rewards: train: -110.88, test: -240.11
#                                             max train reward: 147.46
#                                 avg_steps: 303.10
#                                 losses:
#                                     actor: mean: -6.35, first: -6.27, last: -6.57
#                                     critic: mean: 1.40, first: 1.15, last: 1.37
#                                 avg_duration: 0.04, upd_duration: 0.87
#
# Epoch 510:
#                                 rewards: train: -214.85, test: -119.74
#                                             max train reward: -52.25
#                                 avg_steps: 687.80
#                                 losses:
#                                     actor: mean: -14.64, first: -15.36, last: -15.83
#                                     critic: mean: 0.97, first: 1.10, last: 0.78
#                                 avg_duration: 0.09, upd_duration: 1.98
#
# Epoch 520:
#                                 rewards: train: -112.31, test: -63.38
#                                             max train reward: 9.50
#                                 avg_steps: 512.90
#                                 losses:
#                                     actor: mean: 5.73, first: 4.33, last: 6.65
#                                     critic: mean: 0.85, first: 0.96, last: 0.81
#                                 avg_duration: 0.07, upd_duration: 1.48
#
# Epoch 530:
#                                 rewards: train: -27.14, test: -48.77
#                                             max train reward: 187.04
#                                 avg_steps: 453.70
#                                 losses:
#                                     actor: mean: 17.23, first: 16.61, last: 17.38
#                                     critic: mean: 0.73, first: 0.67, last: 0.82
#                                 avg_duration: 0.06, upd_duration: 1.32
#
# Epoch 540:
#                                 rewards: train: -21.67, test: -171.59
#                                             max train reward: 136.15
#                                 avg_steps: 507.20
#                                 losses:
#                                     actor: mean: 11.27, first: 11.96, last: 12.02
#                                     critic: mean: 1.09, first: 1.34, last: 1.13
#                                 avg_duration: 0.07, upd_duration: 1.45
#
# Epoch 550:
#                                 rewards: train: -67.80, test: -174.53
#                                             max train reward: 180.12
#                                 avg_steps: 524.70
#                                 losses:
#                                     actor: mean: -0.54, first: 0.30, last: -1.63
#                                     critic: mean: 1.21, first: 1.18, last: 1.21
#                                 avg_duration: 0.07, upd_duration: 1.52
#
# Epoch 560:
#                                 rewards: train: -103.75, test: -99.47
#                                             max train reward: -60.07
#                                 avg_steps: 340.10
#                                 losses:
#                                     actor: mean: -17.00, first: -16.03, last: -17.31
#                                     critic: mean: 1.50, first: 1.85, last: 1.37
#                                 avg_duration: 0.05, upd_duration: 0.97
#
# Epoch 570:
#                                 rewards: train: -209.21, test: -69.25
#                                             max train reward: -38.10
#                                 avg_steps: 532.70
#                                 losses:
#                                     actor: mean: -18.36, first: -19.46, last: -17.20
#                                     critic: mean: 1.39, first: 1.26, last: 1.37
#                                 avg_duration: 0.07, upd_duration: 1.54
#
# Epoch 580:
#                                 rewards: train: -34.68, test: -19.78
#                                             max train reward: 31.93
#                                 avg_steps: 235.70
#                                 losses:
#                                     actor: mean: -11.35, first: -12.03, last: -10.35
#                                     critic: mean: 0.93, first: 1.09, last: 1.24
#                                 avg_duration: 0.03, upd_duration: 0.69
#
# Epoch 590:
#                                 rewards: train: -18.61, test: -30.89
#                                             max train reward: 25.12
#                                 avg_steps: 189.40
#                                 losses:
#                                     actor: mean: -15.29, first: -16.65, last: -14.79
#                                     critic: mean: 1.06, first: 1.13, last: 1.04
#                                 avg_duration: 0.03, upd_duration: 0.54
#
# Epoch 600:
#                                 rewards: train: -34.35, test: -29.14
#                                             max train reward: 14.45
#                                 avg_steps: 158.80
#                                 losses:
#                                     actor: mean: -8.70, first: -9.71, last: -8.93
#                                     critic: mean: 2.14, first: 1.99, last: 2.39
#                                 avg_duration: 0.02, upd_duration: 0.45
#
# Epoch 610:
#                                 rewards: train: -23.40, test: -48.36
#                                             max train reward: -12.94
#                                 avg_steps: 110.20
#                                 losses:
#                                     actor: mean: -24.27, first: -23.78, last: -23.69
#                                     critic: mean: 2.36, first: 2.65, last: 3.11
#                                 avg_duration: 0.02, upd_duration: 0.32
#
# Epoch 620:
#                                 rewards: train: -47.90, test: -108.05
#                                             max train reward: 4.79
#                                 avg_steps: 114.60
#                                 losses:
#                                     actor: mean: -31.23, first: -31.40, last: -33.68
#                                     critic: mean: 2.51, first: 2.44, last: 2.64
#                                 avg_duration: 0.02, upd_duration: 0.34
#
# Epoch 630:
#                                 rewards: train: -538.14, test: -169.55
#                                             max train reward: 16.40
#                                 avg_steps: 414.50
#                                 losses:
#                                     actor: mean: -28.66, first: -29.81, last: -27.74
#                                     critic: mean: 2.76, first: 2.73, last: 2.81
#                                 avg_duration: 0.06, upd_duration: 1.24
#
# Epoch 640:
#                                 rewards: train: -210.24, test: -123.18
#                                             max train reward: -90.49
#                                 avg_steps: 438.00
#                                 losses:
#                                     actor: mean: -27.11, first: -27.20, last: -27.86
#                                     critic: mean: 2.06, first: 1.62, last: 2.19
#                                 avg_duration: 0.06, upd_duration: 1.30
#
# Epoch 650:
#                                 rewards: train: -320.84, test: -163.38
#                                             max train reward: -54.15
#                                 avg_steps: 559.80
#                                 losses:
#                                     actor: mean: -42.63, first: -42.27, last: -42.42
#                                     critic: mean: 1.70, first: 2.03, last: 1.62
#                                 avg_duration: 0.08, upd_duration: 1.61
#
# Epoch 660:
#                                 rewards: train: -2.16, test: -127.88
#                                             max train reward: -2.16
#                                 avg_steps: 400.10
#                                 losses:
#                                     actor: mean: -25.11, first: -25.89, last: -24.41
#                                     critic: mean: 0.89, first: 0.92, last: 0.99
#                                 avg_duration: 0.05, upd_duration: 1.16
#
# Epoch 670:
#                                 rewards: train: -109.12, test: -109.92
#                                             max train reward: -7.18
#                                 avg_steps: 420.90
#                                 losses:
#                                     actor: mean: -17.87, first: -18.89, last: -16.97
#                                     critic: mean: 0.79, first: 0.63, last: 0.68
#                                 avg_duration: 0.06, upd_duration: 1.21
#
# Epoch 680:
#                                 rewards: train: -163.29, test: -123.22
#                                             max train reward: -48.45
#                                 avg_steps: 331.90
#                                 losses:
#                                     actor: mean: -3.18, first: -3.29, last: -4.07
#                                     critic: mean: 0.93, first: 0.98, last: 0.80
#                                 avg_duration: 0.05, upd_duration: 0.97
#
# Epoch 690:
#                                 rewards: train: -226.66, test: -233.83
#                                             max train reward: 10.03
#                                 avg_steps: 497.70
#                                 losses:
#                                     actor: mean: -16.17, first: -17.10, last: -16.59
#                                     critic: mean: 0.95, first: 0.86, last: 1.32
#                                 avg_duration: 0.07, upd_duration: 1.45
#
# Epoch 700:
#                                 rewards: train: -267.96, test: -88.57
#                                             max train reward: 51.54
#                                 avg_steps: 451.00
#                                 losses:
#                                     actor: mean: -14.03, first: -14.18, last: -14.17
#                                     critic: mean: 0.77, first: 0.96, last: 0.79
#                                 avg_duration: 0.06, upd_duration: 1.34
#
# Epoch 710:
#                                 rewards: train: -119.04, test: -136.72
#                                             max train reward: -108.18
#                                 avg_steps: 82.60
#                                 losses:
#                                     actor: mean: 2.14, first: 1.24, last: 3.92
#                                     critic: mean: 1.09, first: 0.96, last: 1.13
#                                 avg_duration: 0.01, upd_duration: 0.24
#
# Epoch 720:
#                                 rewards: train: 145.15, test: -17.20
#                                             max train reward: 229.40
#                                 avg_steps: 249.10
#                                 losses:
#                                     actor: mean: 1.47, first: 2.34, last: 0.78
#                                     critic: mean: 1.12, first: 0.99, last: 1.20
#                                 avg_duration: 0.04, upd_duration: 0.73
#
# Epoch 730:
#                                 rewards: train: -45.52, test: -67.70
#                                             max train reward: 206.42
#                                 avg_steps: 282.30
#                                 losses:
#                                     actor: mean: -4.69, first: -3.88, last: -4.28
#                                     critic: mean: 1.41, first: 1.73, last: 1.47
#                                 avg_duration: 0.04, upd_duration: 0.82
#
# Epoch 740:
#                                 rewards: train: -33.14, test: 10.51
#                                             max train reward: 47.10
#                                 avg_steps: 155.90
#                                 losses:
#                                     actor: mean: -4.45, first: -4.95, last: -6.25
#                                     critic: mean: 1.38, first: 0.83, last: 1.04
#                                 avg_duration: 0.02, upd_duration: 0.44
#
# Epoch 750:
#                                 rewards: train: -90.04, test: -69.08
#                                             max train reward: -14.98
#                                 avg_steps: 194.90
#                                 losses:
#                                     actor: mean: -5.91, first: -6.04, last: -4.57
#                                     critic: mean: 1.61, first: 1.64, last: 1.32
#                                 avg_duration: 0.03, upd_duration: 0.57
#
# Epoch 760:
#                                 rewards: train: -91.93, test: -67.04
#                                             max train reward: 239.56
#                                 avg_steps: 337.60
#                                 losses:
#                                     actor: mean: -7.74, first: -6.83, last: -9.01
#                                     critic: mean: 1.63, first: 1.36, last: 1.62
#                                 avg_duration: 0.05, upd_duration: 0.97
#
# Epoch 770:
#                                 rewards: train: -122.87, test: -123.52
#                                             max train reward: 4.62
#                                 avg_steps: 241.20
#                                 losses:
#                                     actor: mean: -24.86, first: -24.23, last: -25.23
#                                     critic: mean: 1.39, first: 1.79, last: 1.97
#                                 avg_duration: 0.03, upd_duration: 0.70
#
# Epoch 780:
#                                 rewards: train: -12.55, test: -1.14
#                                             max train reward: 20.55
#                                 avg_steps: 173.30
#                                 losses:
#                                     actor: mean: -27.75, first: -26.90, last: -28.98
#                                     critic: mean: 1.58, first: 1.54, last: 1.16
#                                 avg_duration: 0.03, upd_duration: 0.51
#
# Epoch 790:
#                                 rewards: train: -78.70, test: 21.74
#                                             max train reward: 15.42
#                                 avg_steps: 195.40
#                                 losses:
#                                     actor: mean: -28.31, first: -28.72, last: -28.27
#                                     critic: mean: 1.35, first: 1.69, last: 2.04
#                                 avg_duration: 0.03, upd_duration: 0.55
#
# Epoch 800:
#                                 rewards: train: -101.11, test: -125.60
#                                             max train reward: -34.02
#                                 avg_steps: 400.60
#                                 losses:
#                                     actor: mean: -30.24, first: -31.39, last: -29.65
#                                     critic: mean: 1.26, first: 1.21, last: 1.05
#                                 avg_duration: 0.05, upd_duration: 1.14
#
# Epoch 810:
#                                 rewards: train: -117.66, test: -69.73
#                                             max train reward: -7.60
#                                 avg_steps: 557.20
#                                 losses:
#                                     actor: mean: -29.50, first: -29.64, last: -29.23
#                                     critic: mean: 1.12, first: 1.11, last: 1.66
#                                 avg_duration: 0.08, upd_duration: 1.64
#
# Epoch 820:
#                                 rewards: train: -116.46, test: -89.71
#                                             max train reward: -29.80
#                                 avg_steps: 197.10
#                                 losses:
#                                     actor: mean: -17.06, first: -18.10, last: -16.48
#                                     critic: mean: 1.06, first: 1.06, last: 1.54
#                                 avg_duration: 0.03, upd_duration: 0.58
#
# Epoch 830:
#                                 rewards: train: -250.24, test: -175.84
#                                             max train reward: 202.06
#                                 avg_steps: 335.20
#                                 losses:
#                                     actor: mean: -8.63, first: -7.83, last: -7.40
#                                     critic: mean: 1.58, first: 2.10, last: 1.52
#                                 avg_duration: 0.05, upd_duration: 0.97
#
# Epoch 840:
#                                 rewards: train: -40.86, test: 94.77
#                                             max train reward: 47.23
#                                 avg_steps: 449.30
#                                 losses:
#                                     actor: mean: -0.30, first: 1.31, last: 1.28
#                                     critic: mean: 1.80, first: 1.58, last: 2.53
#                                 avg_duration: 0.06, upd_duration: 1.28
#
# Epoch 850:
#                                 rewards: train: -107.05, test: 19.97
#                                             max train reward: 230.79
#                                 avg_steps: 378.00
#                                 losses:
#                                     actor: mean: -2.05, first: -2.48, last: -4.71
#                                     critic: mean: 1.98, first: 1.91, last: 2.06
#                                 avg_duration: 0.05, upd_duration: 1.09
#
# Epoch 860:
#                                 rewards: train: -41.44, test: -113.75
#                                             max train reward: 233.24
#                                 avg_steps: 653.80
#                                 losses:
#                                     actor: mean: -3.25, first: -2.98, last: -2.87
#                                     critic: mean: 1.84, first: 2.42, last: 2.63
#                                 avg_duration: 0.09, upd_duration: 1.89
#
# Epoch 870:
#                                 rewards: train: -156.36, test: -194.62
#                                             max train reward: 242.30
#                                 avg_steps: 733.60
#                                 losses:
#                                     actor: mean: -14.53, first: -15.92, last: -13.94
#                                     critic: mean: 1.01, first: 0.75, last: 0.56
#                                 avg_duration: 0.10, upd_duration: 2.13
#
# Epoch 880:
#                                 rewards: train: 34.41, test: 22.12
#                                             max train reward: 34.41
#                                 avg_steps: 589.50
#                                 losses:
#                                     actor: mean: -8.53, first: -8.63, last: -8.42
#                                     critic: mean: 0.94, first: 0.88, last: 1.07
#                                 avg_duration: 0.08, upd_duration: 1.72
#
# Epoch 890:
#                                 rewards: train: -215.40, test: -93.15
#                                             max train reward: 21.06
#                                 avg_steps: 298.00
#                                 losses:
#                                     actor: mean: -7.95, first: -8.28, last: -9.26
#                                     critic: mean: 1.40, first: 1.16, last: 1.16
#                                 avg_duration: 0.04, upd_duration: 0.87
#
# Epoch 900:
#                                 rewards: train: -31.08, test: -131.01
#                                             max train reward: 123.92
#                                 avg_steps: 208.20
#                                 losses:
#                                     actor: mean: -1.77, first: -2.98, last: -1.50
#                                     critic: mean: 1.71, first: 2.15, last: 1.63
#                                 avg_duration: 0.03, upd_duration: 0.61
#
# Epoch 910:
#                                 rewards: train: -45.70, test: -122.52
#                                             max train reward: 64.25
#                                 avg_steps: 392.10
#                                 losses:
#                                     actor: mean: -1.86, first: -0.62, last: -1.88
#                                     critic: mean: 1.86, first: 2.08, last: 2.11
#                                 avg_duration: 0.06, upd_duration: 1.12
#
# Epoch 920:
#                                 rewards: train: -150.78, test: -153.47
#                                             max train reward: -4.78
#                                 avg_steps: 245.00
#                                 losses:
#                                     actor: mean: -3.13, first: -3.16, last: -2.22
#                                     critic: mean: 1.47, first: 1.48, last: 1.45
#                                 avg_duration: 0.04, upd_duration: 0.72
#
# Epoch 930:
#                                 rewards: train: -137.53, test: -126.37
#                                             max train reward: -14.30
#                                 avg_steps: 299.30
#                                 losses:
#                                     actor: mean: -4.78, first: -5.13, last: -5.78
#                                     critic: mean: 1.82, first: 1.51, last: 1.72
#                                 avg_duration: 0.04, upd_duration: 0.87
#
# Epoch 940:
#                                 rewards: train: -8.92, test: -44.57
#                                             max train reward: -8.92
#                                 avg_steps: 166.10
#                                 losses:
#                                     actor: mean: -7.88, first: -9.30, last: -7.00
#                                     critic: mean: 2.19, first: 1.79, last: 2.11
#                                 avg_duration: 0.02, upd_duration: 0.49
#
# Epoch 950:
#                                 rewards: train: 2.18, test: -48.23
#                                             max train reward: 2.18
#                                 avg_steps: 116.30
#                                 losses:
#                                     actor: mean: -6.95, first: -5.25, last: -6.49
#                                     critic: mean: 1.95, first: 1.82, last: 2.47
#                                 avg_duration: 0.02, upd_duration: 0.35
#
# Epoch 960:
#                                 rewards: train: -1.01, test: -1.19
#                                             max train reward: -1.01
#                                 avg_steps: 133.80
#                                 losses:
#                                     actor: mean: -14.06, first: -12.64, last: -14.45
#                                     critic: mean: 1.80, first: 1.97, last: 1.71
#                                 avg_duration: 0.02, upd_duration: 0.39
#
# Epoch 970:
#                                 rewards: train: -47.67, test: -13.40
#                                             max train reward: 27.09
#                                 avg_steps: 139.80
#                                 losses:
#                                     actor: mean: -18.08, first: -18.03, last: -17.08
#                                     critic: mean: 1.97, first: 2.21, last: 2.36
#                                 avg_duration: 0.02, upd_duration: 0.43
#
# Epoch 980:
# ...
#                                     critic: mean: 1.63, first: 1.50, last: 1.66
#                                 avg_duration: 0.05, upd_duration: 0.97
#
# Epoch 3190:
#                                 rewards: train: -138.98, test: -32.30
#                                             max train reward: 246.23
#                                 avg_steps: 187.90
#                                 losses:
#                                     actor: mean: -33.95, first: -32.84, last: -34.64
#                                     critic: mean: 1.53, first: 2.07, last: 1.71
#                                 avg_duration: 0.03, upd_duration: 0.60
#
# Epoch 3200:
#                                 rewards: train: -74.84, test: -88.06
#                                             max train reward: 43.19
#                                 avg_steps: 211.00
#                                 losses:
#                                     actor: mean: -29.75, first: -28.92, last: -29.37
#                                     critic: mean: 1.63, first: 1.40, last: 1.13
#                                 avg_duration: 0.03, upd_duration: 0.61
#
# Epoch 3210:
#                                 rewards: train: -61.89, test: -49.16
#                                             max train reward: -18.32
#                                 avg_steps: 111.60
#                                 losses:
#                                     actor: mean: -23.13, first: -22.68, last: -23.99
#                                     critic: mean: 1.69, first: 1.99, last: 1.90
#                                 avg_duration: 0.02, upd_duration: 0.33
#
# Epoch 3220:
#                                 rewards: train: -95.87, test: 17.32
#                                             max train reward: 155.09
#                                 avg_steps: 174.00
#                                 losses:
#                                     actor: mean: -19.22, first: -19.88, last: -20.47
#                                     critic: mean: 1.62, first: 1.45, last: 1.61
#                                 avg_duration: 0.03, upd_duration: 0.50
#
# Epoch 3230:
#                                 rewards: train: -31.54, test: 23.48
#                                             max train reward: 195.20
#                                 avg_steps: 243.50
#                                 losses:
#                                     actor: mean: -8.10, first: -8.74, last: -9.41
#                                     critic: mean: 1.54, first: 1.53, last: 1.52
#                                 avg_duration: 0.04, upd_duration: 0.71
#
# Epoch 3240:
#                                 rewards: train: -2.18, test: -13.03
#                                             max train reward: 264.53
#                                 avg_steps: 221.00
#                                 losses:
#                                     actor: mean: -21.41, first: -21.35, last: -21.36
#                                     critic: mean: 1.63, first: 1.69, last: 1.98
#                                 avg_duration: 0.03, upd_duration: 0.66
#
# Epoch 3250:
#                                 rewards: train: -69.70, test: -59.69
#                                             max train reward: 246.98
#                                 avg_steps: 275.00
#                                 losses:
#                                     actor: mean: -22.96, first: -22.78, last: -24.50
#                                     critic: mean: 1.55, first: 1.43, last: 1.25
#                                 avg_duration: 0.04, upd_duration: 0.81
#
# Epoch 3260:
#                                 rewards: train: 208.70, test: 25.74
#                                             max train reward: 208.70
#                                 avg_steps: 326.40
#                                 losses:
#                                     actor: mean: -11.99, first: -13.31, last: -10.93
#                                     critic: mean: 1.64, first: 1.58, last: 1.73
#                                 avg_duration: 0.05, upd_duration: 0.96
#
# Epoch 3270:
#                                 rewards: train: 169.90, test: -82.98
#                                             max train reward: 181.21
#                                 avg_steps: 383.70
#                                 losses:
#                                     actor: mean: -3.02, first: -2.78, last: -3.54
#                                     critic: mean: 1.82, first: 1.60, last: 1.78
#                                 avg_duration: 0.05, upd_duration: 1.12
#
# Epoch 3280:
#                                 rewards: train: -97.58, test: 110.66
#                                             max train reward: -79.43
#                                 avg_steps: 323.20
#                                 losses:
#                                     actor: mean: -4.91, first: -5.12, last: -5.22
#                                     critic: mean: 1.73, first: 1.83, last: 1.43
#                                 avg_duration: 0.04, upd_duration: 0.93
#
# Epoch 3290:
#                                 rewards: train: -267.19, test: -152.88
#                                             max train reward: -48.22
#                                 avg_steps: 423.70
#                                 losses:
#                                     actor: mean: -2.84, first: -3.04, last: -3.08
#                                     critic: mean: 1.31, first: 1.12, last: 1.31
#                                 avg_duration: 0.06, upd_duration: 1.22
#
# Epoch 3300:
#                                 rewards: train: -170.92, test: -142.28
#                                             max train reward: -91.41
#                                 avg_steps: 285.00
#                                 losses:
#                                     actor: mean: 0.19, first: -0.14, last: 0.61
#                                     critic: mean: 1.01, first: 1.05, last: 1.05
#                                 avg_duration: 0.04, upd_duration: 0.81
#
# Epoch 3310:
#                                 rewards: train: -161.17, test: -100.99
#                                             max train reward: -48.89
#                                 avg_steps: 413.10
#                                 losses:
#                                     actor: mean: 4.46, first: 3.81, last: 4.60
#                                     critic: mean: 1.10, first: 0.93, last: 1.21
#                                 avg_duration: 0.06, upd_duration: 1.21
#
# Epoch 3320:
#                                 rewards: train: 128.39, test: 29.37
#                                             max train reward: 128.39
#                                 avg_steps: 399.30
#                                 losses:
#                                     actor: mean: 14.45, first: 14.80, last: 14.52
#                                     critic: mean: 1.11, first: 1.01, last: 1.18
#                                 avg_duration: 0.06, upd_duration: 1.16
#
# Epoch 3330:
#                                 rewards: train: -88.84, test: 51.51
#                                             max train reward: 208.81
#                                 avg_steps: 431.20
#                                 losses:
#                                     actor: mean: 14.41, first: 14.87, last: 14.96
#                                     critic: mean: 0.98, first: 1.13, last: 0.93
#                                 avg_duration: 0.06, upd_duration: 1.25
#
# Epoch 3340:
#                                 rewards: train: -233.50, test: -198.39
#                                             max train reward: 159.92
#                                 avg_steps: 310.90
#                                 losses:
#                                     actor: mean: 7.77, first: 7.43, last: 8.54
#                                     critic: mean: 1.26, first: 1.40, last: 1.41
#                                 avg_duration: 0.04, upd_duration: 0.89
#
# Epoch 3350:
#                                 rewards: train: 251.48, test: -258.66
#                                             max train reward: 251.48
#                                 avg_steps: 413.80
#                                 losses:
#                                     actor: mean: 2.17, first: 1.53, last: 0.86
#                                     critic: mean: 1.58, first: 1.52, last: 1.60
#                                 avg_duration: 0.06, upd_duration: 1.20
#
# Epoch 3360:
#                                 rewards: train: 270.16, test: -167.82
#                                             max train reward: 270.16
#                                 avg_steps: 411.30
#                                 losses:
#                                     actor: mean: 2.82, first: 3.68, last: 0.82
#                                     critic: mean: 1.39, first: 1.12, last: 1.51
#                                 avg_duration: 0.06, upd_duration: 1.19
#
# Epoch 3370:
#                                 rewards: train: -114.28, test: -103.86
#                                             max train reward: 251.35
#                                 avg_steps: 363.80
#                                 losses:
#                                     actor: mean: -15.79, first: -16.27, last: -16.62
#                                     critic: mean: 1.52, first: 1.40, last: 1.59
#                                 avg_duration: 0.05, upd_duration: 1.04
#
# Epoch 3380:
#                                 rewards: train: -695.15, test: -77.16
#                                             max train reward: -119.19
#                                 avg_steps: 400.30
#                                 losses:
#                                     actor: mean: -5.80, first: -6.12, last: -5.92
#                                     critic: mean: 1.92, first: 2.15, last: 1.67
#                                 avg_duration: 0.06, upd_duration: 1.19
#
# Epoch 3390:
#                                 rewards: train: -74.02, test: -169.48
#                                             max train reward: 275.70
#                                 avg_steps: 305.60
#                                 losses:
#                                     actor: mean: -8.15, first: -9.32, last: -8.38
#                                     critic: mean: 2.04, first: 2.13, last: 2.03
#                                 avg_duration: 0.04, upd_duration: 0.91
#
# Epoch 3400:
#                                 rewards: train: 138.85, test: -42.34
#                                             max train reward: 235.62
#                                 avg_steps: 268.70
#                                 losses:
#                                     actor: mean: -13.72, first: -13.79, last: -11.64
#                                     critic: mean: 1.57, first: 2.25, last: 1.49
#                                 avg_duration: 0.04, upd_duration: 0.77
#
# Epoch 3410:
#                                 rewards: train: -66.73, test: -51.19
#                                             max train reward: 17.30
#                                 avg_steps: 128.10
#                                 losses:
#                                     actor: mean: -7.75, first: -9.69, last: -6.06
#                                     critic: mean: 1.55, first: 1.33, last: 1.76
#                                 avg_duration: 0.02, upd_duration: 0.39
#
# Epoch 3420:
#                                 rewards: train: -191.52, test: -77.98
#                                             max train reward: 11.36
#                                 avg_steps: 116.80
#                                 losses:
#                                     actor: mean: -1.13, first: -1.51, last: -1.03
#                                     critic: mean: 1.66, first: 1.83, last: 1.26
#                                 avg_duration: 0.02, upd_duration: 0.35
#
# Epoch 3430:
#                                 rewards: train: 37.39, test: -262.49
#                                             max train reward: 137.70
#                                 avg_steps: 244.60
#                                 losses:
#                                     actor: mean: 8.20, first: 6.88, last: 8.01
#                                     critic: mean: 2.09, first: 2.33, last: 1.91
#                                 avg_duration: 0.03, upd_duration: 0.72
#
# Epoch 3440:
#                                 rewards: train: -23.82, test: -69.37
#                                             max train reward: 233.48
#                                 avg_steps: 363.40
#                                 losses:
#                                     actor: mean: -13.29, first: -12.76, last: -14.34
#                                     critic: mean: 2.18, first: 2.32, last: 2.34
#                                 avg_duration: 0.05, upd_duration: 1.05
#
# Epoch 3450:
#                                 rewards: train: -30.35, test: -15.04
#                                             max train reward: -0.20
#                                 avg_steps: 209.50
#                                 losses:
#                                     actor: mean: -9.99, first: -10.29, last: -8.15
#                                     critic: mean: 2.06, first: 1.96, last: 2.21
#                                 avg_duration: 0.03, upd_duration: 0.61
#
# Epoch 3460:
#                                 rewards: train: 4.57, test: -146.88
#                                             max train reward: 4.57
#                                 avg_steps: 133.10
#                                 losses:
#                                     actor: mean: -7.21, first: -5.90, last: -7.13
#                                     critic: mean: 2.31, first: 2.25, last: 2.01
#                                 avg_duration: 0.02, upd_duration: 0.39
#
# Epoch 3470:
#                                 rewards: train: -148.81, test: -129.60
#                                             max train reward: 61.80
#                                 avg_steps: 294.00
#                                 losses:
#                                     actor: mean: -11.10, first: -10.11, last: -13.58
#                                     critic: mean: 2.66, first: 2.44, last: 2.46
#                                 avg_duration: 0.04, upd_duration: 0.86
#
# Epoch 3480:
#                                 rewards: train: -11.97, test: -12.40
#                                             max train reward: 1.79
#                                 avg_steps: 369.10
#                                 losses:
#                                     actor: mean: -14.50, first: -15.93, last: -15.81
#                                     critic: mean: 2.38, first: 2.02, last: 1.84
#                                 avg_duration: 0.06, upd_duration: 1.17
#
# Epoch 3490:
#                                 rewards: train: -107.49, test: -103.30
#                                             max train reward: -2.29
#                                 avg_steps: 356.00
#                                 losses:
#                                     actor: mean: -13.78, first: -12.62, last: -14.64
#                                     critic: mean: 2.06, first: 2.01, last: 2.34
#                                 avg_duration: 0.05, upd_duration: 1.11
#
# Epoch 3500:
#                                 rewards: train: -191.26, test: -123.96
#                                             max train reward: -26.64
#                                 avg_steps: 444.60
#                                 losses:
#                                     actor: mean: -13.30, first: -13.29, last: -14.91
#                                     critic: mean: 1.21, first: 1.52, last: 1.10
#                                 avg_duration: 0.07, upd_duration: 1.36

# %%
# plot all
plt.figure(figsize=(25, 15))
plt.subplot(3, 3, 1)
plt.plot(episode_rewards)
plt.title("Episode rewards")
plt.subplot(3, 3, 2)
plt.plot(np.arange(len(test_rewards))*10, test_rewards)
# plt.scatter(np.arange(len(test_rewards))*10, test_rewards, s=2, alpha=0.2)
plt.title("Test rewards")
plt.subplot(3, 3, 3)
plt.plot(episode_steps)
plt.title("Episode steps")
plt.subplot(3, 3, 4)
plt.plot(ep_durations)
plt.title("Episode durations")
plt.subplot(3, 3, 5)
plt.plot(upd_durations)
plt.title("Update durations")
plt.subplot(3, 3, 6)
plt.plot(ep_actor_losses)
plt.title("Episode actor loss")
plt.subplot(3, 3, 7)
plt.plot(ep_critic_losses)
plt.title("Episode critic loss")
plt.show()

# %%
agent.save()

# %%
agent = TD3(env, env_string)
agent.load()

# %%
# import dill as pickle
# # save agent using pickle
# with open("agent.pkl", "wb") as f:
#     data = pickle.dumps(agent)
#     f.write(data)

# %%
# # load agent.pkl
# agent = pickle.load(open("agent.pkl", "rb"))

# %%
# save policy and q function
# torch.save(agent.policy.state_dict(), "policy.pt")
# torch.save(agent.q1.state_dict(), "q1.pt")
# torch.save(agent.q2.state_dict(), "q2.pt")

# %%
# from feedforward import FeedforwardNetwork
# pol_test = FeedforwardNetwork(18,4, h=64)
# pol_test.load_state_dict(torch.load("policy.pt"))
# Out:
# <All keys matched successfully>

# %%
# # plot
# plt.figure(figsize=(10, 5))
# plt.plot(ep_rewards, label="train")
# plt.xlabel("epochs")
# plt.ylabel("reward")

# test_epochs = np.arange(0, len(test_rewards)) * 10
# plt.scatter(test_epochs, test_rewards, label="test", color="red", marker="x", zorder=100, s=10)

# %%
# env = gym.make(env_string, render_mode="rgb_array")

# %%
from tqdm import tqdm

# %%
wins = 0
draws = 0
for i in range(100):
    agent.test(render_mode=None, noise_enabled=False)
    if agent.env.winner == 1:
        wins += 1
    elif agent.env.winner == 0:
        draws += 1

print("wins: ", wins)
print("draws: ", draws)
print("losses: ", 100 - wins - draws)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 5
#       3 for i in range(100):
#       4     agent.test(render_mode=None, noise_enabled=False)
# ----> 5     if agent.env.winner == 1:
#       6         wins += 1
#       7     elif agent.env.winner == 0:
#
# File ~/mambaforge/envs/rl/lib/python3.8/site-packages/gymnasium/core.py:282, in Wrapper.__getattr__(self, name)
#     280 elif name.startswith("_"):
#     281     raise AttributeError(f"accessing private attribute '{name}' is prohibited")
# --> 282 return getattr(self.env, name)
#
# File ~/mambaforge/envs/rl/lib/python3.8/site-packages/gymnasium/core.py:282, in Wrapper.__getattr__(self, name)
#     280 elif name.startswith("_"):
#     281     raise AttributeError(f"accessing private attribute '{name}' is prohibited")
# --> 282 return getattr(self.env, name)
#
# File ~/mambaforge/envs/rl/lib/python3.8/site-packages/gymnasium/core.py:282, in Wrapper.__getattr__(self, name)
#     280 elif name.startswith("_"):
#     281     raise AttributeError(f"accessing private attribute '{name}' is prohibited")
# --> 282 return getattr(self.env, name)
#
# AttributeError: 'LunarLander' object has no attribute 'winner'

# %%
agent.env = h_env.HockeyEnv(mode=h_env.HockeyEnv.NORMAL)

# %%
agent.test(noise_enabled=False, render_mode="human")
agent.env.reset()
# Out:
# (array([ 1.7919540e-04,  1.4211233e+00,  1.8129159e-02,  4.5348006e-01,
#         -2.0079417e-04, -4.1064834e-03,  0.0000000e+00,  0.0000000e+00],
#        dtype=float32),
#  {})

# %%
class MyHockeyOpponent:
    def __init__(self):
        pass

    def act(self, obs):
        return agent.get_action(obs, noise=False)
        # return np.array([0, 0, 0.5, 0])
    
# agent.hockey_opponent = MyHockeyOpponent()
agent.hockey_opponent = h_env.BasicOpponent(weak=False)

# %%
agent.hockey_opponent = h_env.BasicOpponent(weak=False)
agent.env = h_env.HockeyEnv(mode=h_env.HockeyEnv.NORMAL)

# %%
for i in range(15):
    agent.test(noise_enabled=False, render_mode="human")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 for i in range(15):
# ----> 2     agent.test(noise_enabled=False, render_mode="human")
#
# File ~/bwSyncAndShare/stud/mast/Sem2/RL/project/RLPowerPucks/algorithms/td3_code_tmp/old/td3.py:576, in TD3.test(self, noise_enabled, render_mode)
#     574 while not done and step < self.steps_max:
#     575     action = self.get_action(state, noise=noise_enabled)
# --> 576     state, reward, terminated, truncated, _ = env.step(action)
#     577     done = terminated or truncated
#     578     rewards.append(reward)
#
# File ~/mambaforge/envs/rl/lib/python3.8/site-packages/gymnasium/wrappers/time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/mambaforge/envs/rl/lib/python3.8/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/mambaforge/envs/rl/lib/python3.8/site-packages/gymnasium/wrappers/env_checker.py:49, in PassiveEnvChecker.step(self, action)
#      47     return env_step_passive_checker(self.env, action)
#      48 else:
# ---> 49     return self.env.step(action)
#
# File ~/mambaforge/envs/rl/lib/python3.8/site-packages/gymnasium/envs/box2d/lunar_lander.py:675, in LunarLander.step(self, action)
#     672     reward = +100
#     674 if self.render_mode == "human":
# --> 675     self.render()
#     676 return np.array(state, dtype=np.float32), reward, terminated, False, {}
#
# File ~/mambaforge/envs/rl/lib/python3.8/site-packages/gymnasium/envs/box2d/lunar_lander.py:787, in LunarLander.render(self)
#     785     self.screen.blit(self.surf, (0, 0))
#     786     pygame.event.pump()
# --> 787     self.clock.tick(self.metadata["render_fps"])
#     788     pygame.display.flip()
#     789 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# # test normal
# env_normal = h_env.HockeyEnv(mode=0)
# agent.env = env_normal
# agent.test(noise_enabled=False, render_mode="human")
# agent.env = env

# %%
# sample from buffer
# state, action, reward, next_state, done = agent.replay_buffer.sample(10)
# state = torch.tensor(state, dtype=torch.float32)
# agent.update_policy(state)

# %%
# combined = torch.cat((state, action), dim=-1)
# qval = agent.q1(combined)
# qval

# %%
# noise_policy = lambda x: agent.get_action(x, noise=True)

# %%
# play(env, noise_policy, steps=1000, render_every=4)

# %%
max(test_rewards)

# %%
# test for some values
state, info = env.reset()
action = agent.get_action(torch.tensor(state, dtype=torch.float32), noise=False)
qval = agent.get_q1(
    torch.tensor(state, dtype=torch.float32), torch.tensor(action, dtype=torch.float32)
)
# print

print("state: ", state)
print("action: ", action)
print("qval: ", qval)
# Out:
# state:  [-0.5729768  0.       ]
# action:  [0.00224565]
# qval:  tensor(-0.3332, grad_fn=<SqueezeBackward0>)

# %%
# %matplotlib inline
q = agent.q1
# plot q function over state space
# sample states
n = 100
x = np.linspace(-1.2, 0.6, n)
y = 0.0
actions = np.linspace(-1.0, 1.0, n)

states = np.zeros((n, 2))
for i in range(n):
    states[i, :] = np.array([x[i], y])

# compute q values
q_values = np.zeros((n, n))
for i in range(n):
    for j in range(n):
        q_values[i, j] = q(torch.hstack((torch.tensor(states[i], dtype=torch.float32), torch.tensor(actions[j], dtype=torch.float32)))).detach().numpy()

policy_actions = np.zeros((n))
for i in range(n):
    policy_actions[i] = agent.get_action(torch.tensor(states[i], dtype=torch.float32), noise=False)

# plot 2d
plt.figure(figsize=(10, 10))
plt.imshow(q_values, extent=[-1.2, 0.6, -1.0, 1.0], aspect="auto")
plt.colorbar()
plt.scatter(states[:, 0], policy_actions, color="red", marker="x", zorder=100, s=10)

plt.xlabel("position")
plt.ylabel("action")
plt.title("Q function")
# Out:
# Text(0.5, 1.0, 'Q function')

# %%
state = np.array([-0.9, 0])
state = torch.tensor(state, dtype=torch.float32)
print(agent.get_action(state, noise=False))


agent.update_policy(state)
# Out:
# [0.03972045]
# 6.6863226890563965

# %%
# from torchviz import make_dot

# # TODO: find performance bottleneck in torch

# state, info = env.reset()
# state = torch.tensor(state, dtype=torch.float32)
# action = agent.policy(state)

# combined = torch.cat((state, action), dim=-1)

# qval = agent.q1(combined)

# grad_plot = make_dot(qval, show_attrs=True, show_saved=True)

# #save grad plot
# grad_plot.format = "png"
# grad_plot.render("grad_plot")
